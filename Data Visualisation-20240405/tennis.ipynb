# %%
import pandas as pd

# %%
titles = [24, 22, 20 ,14]
ds = pd.Series(titles)
ds
# Out:
# 0    24
# 1    22
# 2    20
# 3    14
# dtype: int64

# %%
ds.index = ['Novak Djokovic', 'Rafael Nadal', 'Roger Federer', 'Pete Sampras']
ds.plot(kind='bar', title='No of titles won by each player', xlabel='Tennis players', ylabel='Titles won')
# Out:
# <Axes: title={'center': 'No of titles won by each player'}, xlabel='Tennis players', ylabel='Titles won'>
